# %%
import pandas as pd
df = pd.read_csv("policy/avg_policy.csv")
columns = df.columns
print('Length of df:', len(df))
df.head()
# Out:
# Length of df: 206730
#      PHASE ROLE HAND  BOARD  POT  RATIO  SPR  HEROBOARD  PROB_FOLD  \
# 0  PREFLOP   SB  Q3s      0    4      2    6          0   0.690196
# 1  PREFLOP   SB  Q3s      0   18      4    0          0   0.698039
# 2  PREFLOP   BB  K6s      0    3      0    6          0   0.501961
# 3  PREFLOP  BTN  A2s      0    2      4    6          0   0.462745
# 4  PREFLOP   SB  74o      0    4      2    6          0   0.925490
#
#    PROB_CHECK  PROB_CALL  PROB_RAISE  PROB_ALL-IN
# 0    0.000000   0.000000    0.305882     0.003922
# 1    0.000000   0.000000    0.290196     0.011765
# 2    0.498039   0.000000    0.000000     0.000000
# 3    0.000000   0.000000    0.423529     0.113725
# 4    0.000000   0.054902    0.019608     0.000000

# %%
df.describe()
# Out:
#                BOARD            POT          RATIO            SPR  \
# count  206730.000000  206730.000000  206730.000000  206730.000000
# mean        5.140134       9.174135       1.251415       4.321768
# std         3.828839       4.473791       1.448324       1.972788
# min         0.000000       2.000000       0.000000       0.000000
# 25%         2.000000       6.000000       0.000000       4.000000
# 50%         5.000000       8.000000       1.000000       5.000000
# 75%         8.000000      10.000000       2.000000       6.000000
# max        14.000000      21.000000       4.000000       6.000000
#
#            HEROBOARD      PROB_FOLD     PROB_CHECK      PROB_CALL  \
# count  206730.000000  206730.000000  206730.000000  206730.000000
# mean        3.689034       0.684077       0.029921       0.018158
# std         2.212710       0.274006       0.109450       0.077659
# min         0.000000       0.000000       0.000000       0.000000
# 25%         4.000000       0.549020       0.000000       0.000000
# 50%         4.000000       0.800000       0.000000       0.000000
# 75%         5.000000       0.898039       0.000000       0.000000
# max         9.000000       1.000000       1.000000       1.000000
#
#           PROB_RAISE    PROB_ALL-IN
# count  206730.000000  206730.000000
# mean        0.246460       0.021384
# std         0.219563       0.085506
# min         0.000000       0.000000
# 25%         0.101961       0.000000
# 50%         0.200000       0.000000
# 75%         0.349020       0.000000
# max         1.000000       0.498039

# %%
for column in columns:
    print(df[column].value_counts())
    print("-" * 100)
# Out:
# PHASE
# FLOP       130181
# TURN        50861
# RIVER       17384
# PREFLOP      8304
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ROLE
# BB     87000
# SB     72085
# BTN    47645
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# HAND
# 92s    2096
# 42s    2045
# 63s    2014
# 53s    2013
# 82s    2009
#        ...
# AQo     763
# QJo     762
# Q6o     754
# AKo     709
# AA      708
# Name: count, Length: 169, dtype: int64
# ----------------------------------------------------------------------------------------------------
# BOARD
# 2     37353
# 8     27142
# 5     21279
# 0     20985
# 1     16690
# 7     13992
# 6     12015
# 3     11473
# 4     10435
# 11     9542
# 14     7346
# 9      6943
# 10     5272
# 13     3331
# 12     2932
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# POT
# 9     31806
# 7     27764
# 18    25411
# 6     22349
# 8     21326
# 10    18840
# 5     13721
# 3     11618
# 11    10920
# 4      9554
# 12     6902
# 21     4928
# 13     1041
# 2       338
# 14      161
# 19       33
# 15       18
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# RATIO
# 0    101256
# 2     37846
# 4     25613
# 1     22742
# 3     19273
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# SPR
# 6    67892
# 5    60164
# 4    40534
# 0    30372
# 3     7595
# 2      173
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# HEROBOARD
# 4    98126
# 0    45295
# 5    39529
# 7    17658
# 9     3871
# 6     1984
# 8      267
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# PROB_FOLD
# 0.898039    22402
# 0.000000    19921
# 0.800000    18731
# 0.850980    18250
# 0.549020    13469
#             ...
# 0.392157        2
# 0.419608        2
# 0.337255        2
# 0.423529        1
# 0.407843        1
# Name: count, Length: 172, dtype: int64
# ----------------------------------------------------------------------------------------------------
# PROB_CHECK
# 0.000000    186831
# 0.333333      8854
# 0.101961       995
# 0.149020       801
# 1.000000       795
#              ...
# 0.737255         1
# 0.541176         1
# 0.156863         1
# 0.776471         1
# 0.760784         1
# Name: count, Length: 182, dtype: int64
# ----------------------------------------------------------------------------------------------------
# PROB_CALL
# 0.000000    193659
# 0.333333      6762
# 0.101961       601
# 0.200000       469
# 0.149020       466
#              ...
# 0.956863         1
# 0.796078         1
# 0.847059         1
# 0.854902         1
# 0.925490         1
# Name: count, Length: 150, dtype: int64
# ----------------------------------------------------------------------------------------------------
# PROB_RAISE
# 0.000000    21833
# 0.101961    20858
# 0.200000    17541
# 0.149020    17033
# 0.333333    15417
#             ...
# 0.368627        7
# 0.192157        6
# 0.235294        5
# 0.239216        4
# 0.482353        3
# Name: count, Length: 130, dtype: int64
# ----------------------------------------------------------------------------------------------------
# PROB_ALL-IN
# 0.000000    192539
# 0.333333      9077
# 0.498039      2047
# 0.250980       650
# 0.003922       605
#              ...
# 0.341176         1
# 0.368627         1
# 0.482353         1
# 0.400000         1
# 0.376471         1
# Name: count, Length: 118, dtype: int64
# ----------------------------------------------------------------------------------------------------

# %%
df_preflop = df[df['PHASE'] == 'PREFLOP']
df_preflop_sb = df_preflop[df_preflop['ROLE'] == 'SB']
df_preflop_sb.describe()
# Out:
#         BOARD          POT        RATIO          SPR  HEROBOARD    PROB_FOLD  \
# count  2831.0  2831.000000  2831.000000  2831.000000     2831.0  2831.000000
# mean      0.0     9.195691     2.192865     4.311904        0.0     0.743990
# std       0.0     4.605865     0.851666     1.814701        0.0     0.199946
# min       0.0     2.000000     1.000000     0.000000        0.0     0.000000
# 25%       0.0     6.000000     2.000000     4.000000        0.0     0.600000
# 50%       0.0     9.000000     2.000000     5.000000        0.0     0.800000
# 75%       0.0    11.000000     3.000000     6.000000        0.0     0.898039
# max       0.0    21.000000     4.000000     6.000000        0.0     1.000000
#
#        PROB_CHECK    PROB_CALL   PROB_RAISE  PROB_ALL-IN
# count      2831.0  2831.000000  2831.000000  2831.000000
# mean          0.0     0.107485     0.144066     0.004459
# std           0.0     0.179679     0.191794     0.025975
# min           0.0     0.000000     0.000000     0.000000
# 25%           0.0     0.000000     0.000000     0.000000
# 50%           0.0     0.000000     0.058824     0.000000
# 75%           0.0     0.168627     0.243137     0.000000
# max           0.0     1.000000     1.000000     0.333333
