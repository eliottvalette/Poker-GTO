# %%
import pandas as pd
df = pd.read_csv("policy/avg_policy.csv")
columns = df.columns
print('Length of df:', len(df))
df.head()
# Out:
# Length of df: 130185
#      PHASE ROLE HAND  BOARD  POT  RATIO  SPR  HEROBOARD  PROB_FOLD  \
# 0  PREFLOP   SB  K7o      0   18      4    0          0   0.792157
# 1  PREFLOP   BB  52o      0   21      3    0          0   0.533333
# 2  PREFLOP  BTN   77      0    3      4    6          0   0.000000
# 3  PREFLOP  BTN   77      0   18      4    0          0   0.513725
# 4  PREFLOP   SB  86s      0    5      2    6          0   0.458824
#
#    PROB_CHECK  PROB_CALL  PROB_RAISE  PROB_ALL-IN
# 0         0.0   0.000000    0.000000     0.207843
# 1         0.0   0.000000    0.000000     0.466667
# 2         0.0   0.407843    0.333333     0.258824
# 3         0.0   0.000000    0.000000     0.486275
# 4         0.0   0.282353    0.258824     0.000000

# %%
df.describe()
# Out:
#                BOARD            POT          RATIO            SPR  \
# count  130185.000000  130185.000000  130185.000000  130185.000000
# mean        5.040227      10.063218       1.367577       4.132619
# std         3.811939       4.453942       1.513990       2.091937
# min         0.000000       3.000000       0.000000       0.000000
# 25%         2.000000       7.000000       0.000000       4.000000
# 50%         5.000000       9.000000       1.000000       5.000000
# 75%         8.000000      11.000000       3.000000       6.000000
# max        14.000000      21.000000       4.000000       6.000000
#
#            HEROBOARD      PROB_FOLD     PROB_CHECK      PROB_CALL  \
# count  130185.000000  130185.000000  130185.000000  130185.000000
# mean        3.582041       0.222446       0.172256       0.113584
# std         2.177940       0.234498       0.193964       0.159458
# min         0.000000       0.000000       0.000000       0.000000
# 25%         4.000000       0.000000       0.000000       0.000000
# 50%         4.000000       0.333333       0.000000       0.000000
# 75%         5.000000       0.333333       0.333333       0.333333
# max         9.000000       1.000000       1.000000       0.882353
#
#           PROB_RAISE    PROB_ALL-IN
# count  130185.000000  130185.000000
# mean        0.256807       0.234907
# std         0.138115       0.178303
# min         0.000000       0.000000
# 25%         0.254902       0.000000
# 50%         0.333333       0.333333
# 75%         0.333333       0.333333
# max         0.498039       0.501961

# %%
for column in columns:
    print(df[column].value_counts())
    print("-" * 100)
# Out:
# PHASE
# FLOP       85653
# TURN       28585
# RIVER       8766
# PREFLOP     7181
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ROLE
# BB     49626
# SB     48230
# BTN    32329
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# HAND
# 72o    1285
# 82o    1244
# 73o    1240
# 83o    1232
# 43o    1230
#        ...
# AQs     443
# KTs     441
# AJs     438
# A9s     438
# K9s     436
# Name: count, Length: 169, dtype: int64
# ----------------------------------------------------------------------------------------------------
# BOARD
# 2     23871
# 8     18375
# 0     15102
# 5     12217
# 1     10209
# 7      9294
# 6      7934
# 3      6670
# 4      5853
# 11     5593
# 14     4321
# 9      4255
# 10     3015
# 13     1868
# 12     1608
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# POT
# 9     21030
# 18    19154
# 7     15500
# 10    14650
# 8     13877
# 6     11132
# 12     7895
# 11     7877
# 4      7519
# 5      5844
# 21     3891
# 13     1209
# 3       338
# 14      171
# 19       60
# 15       37
# 16        1
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# RATIO
# 0    61310
# 2    21792
# 4    19383
# 3    14611
# 1    13089
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# SPR
# 6    40333
# 5    34907
# 4    26048
# 0    23105
# 3     5697
# 2       94
# 1        1
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# HEROBOARD
# 4    63469
# 0    29846
# 5    24099
# 7     9764
# 9     1773
# 6     1110
# 8      124
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# PROB_FOLD
# 0.000000    62272
# 0.333333    36752
# 0.501961    12886
# 0.498039     2764
# 0.505882      425
#             ...
# 0.894118       32
# 0.760784       31
# 0.886275       31
# 0.909804       26
# 1.000000       24
# Name: count, Length: 172, dtype: int64
# ----------------------------------------------------------------------------------------------------
# PROB_CHECK
# 0.000000    68933
# 0.333333    48913
# 0.341176      421
# 0.349020      386
# 0.356863      329
#             ...
# 0.949020        1
# 0.933333        1
# 0.831373        1
# 0.941176        1
# 0.956863        1
# Name: count, Length: 168, dtype: int64
# ----------------------------------------------------------------------------------------------------
# PROB_CALL
# 0.000000    85514
# 0.333333    37438
# 0.329412      417
# 0.337255      408
# 0.325490      312
#             ...
# 0.713725        1
# 0.737255        1
# 0.588235        1
# 0.682353        1
# 0.694118        1
# Name: count, Length: 202, dtype: int64
# ----------------------------------------------------------------------------------------------------
# PROB_RAISE
# 0.333333    84709
# 0.000000    27264
# 0.329412      856
# 0.325490      649
# 0.337255      588
#             ...
# 0.019608       23
# 0.003922       22
# 0.007843       21
# 0.494118       15
# 0.498039       12
# Name: count, Length: 128, dtype: int64
# ----------------------------------------------------------------------------------------------------
# PROB_ALL-IN
# 0.333333    50638
# 0.000000    39531
# 0.498039    12835
# 0.501961     2696
# 0.329412      497
#             ...
# 0.376471       49
# 0.368627       49
# 0.360784       48
# 0.372549       46
# 0.352941       43
# Name: count, Length: 129, dtype: int64
# ----------------------------------------------------------------------------------------------------

# %%
df_preflop = df[df['PHASE'] == 'PREFLOP']
df_preflop_sb = df_preflop[df_preflop['ROLE'] == 'SB']
df_preflop_sb.describe()
# Out:
#         BOARD          POT        RATIO          SPR  HEROBOARD    PROB_FOLD  \
# count  2359.0  2359.000000  2359.000000  2359.000000     2359.0  2359.000000
# mean      0.0    10.075032     2.283171     4.164053        0.0     0.417124
# std       0.0     4.627137     0.883080     1.915907        0.0     0.197641
# min       0.0     3.000000     1.000000     0.000000        0.0     0.000000
# 25%       0.0     7.000000     2.000000     4.000000        0.0     0.341176
# 50%       0.0    10.000000     2.000000     4.000000        0.0     0.407843
# 75%       0.0    12.000000     3.000000     6.000000        0.0     0.529412
# max       0.0    21.000000     4.000000     6.000000        0.0     0.992157
#
#        PROB_CHECK    PROB_CALL   PROB_RAISE  PROB_ALL-IN
# count      2359.0  2359.000000  2359.000000  2359.000000
# mean          0.0     0.255795     0.155200     0.171881
# std           0.0     0.161569     0.147553     0.150104
# min           0.0     0.000000     0.000000     0.000000
# 25%           0.0     0.105882     0.000000     0.000000
# 50%           0.0     0.325490     0.184314     0.192157
# 75%           0.0     0.341176     0.301961     0.298039
# max           0.0     0.835294     0.454902     0.498039
